# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("online_retail.csv" )

# %%
df
# Out:
#          index InvoiceNo StockCode                          Description  \
# 0            0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1            1    536365     71053                  WHITE METAL LANTERN
# 2            2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3            3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4            4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...        ...       ...       ...                                  ...
# 541904  541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 541905  541905    581587     22899         CHILDREN'S APRON DOLLY GIRL
# 541906  541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 541907  541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 541908  541908    581587     22138        BAKING SET 9 PIECE RETROSPOT
#
#         Quantity      InvoiceDate  UnitPrice  CustomerID         Country
# 0              6   12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1              6   12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2              8   12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3              6   12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4              6   12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...          ...              ...        ...         ...             ...
# 541904        12  12/9/2011 12:50       0.85     12680.0          France
# 541905         6  12/9/2011 12:50       2.10     12680.0          France
# 541906         4  12/9/2011 12:50       4.15     12680.0          France
# 541907         4  12/9/2011 12:50       4.15     12680.0          France
# 541908         3  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 9 columns]

# %%
df.head(5419)
# Out:
#       index InvoiceNo StockCode                          Description  \
# 0         0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1         1    536365     71053                  WHITE METAL LANTERN
# 2         2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3         3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4         4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...     ...       ...       ...                                  ...
# 5414   5414    536862     22423             REGENCY CAKESTAND 3 TIER
# 5415   5415    536862     22429           ENAMEL MEASURING JUG CREAM
# 5416   5416    536862     22457      NATURAL SLATE HEART CHALKBOARD
# 5417   5417    536862     22467                    GUMBALL COAT RACK
# 5418   5418    536862     22469                HEART OF WICKER SMALL
#
#       Quantity      InvoiceDate  UnitPrice  CustomerID         Country
# 0            6   12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1            6   12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2            8   12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3            6   12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4            6   12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...        ...              ...        ...         ...             ...
# 5414         6  12/3/2010 11:13      25.49         NaN  United Kingdom
# 5415         1  12/3/2010 11:13       8.47         NaN  United Kingdom
# 5416         1  12/3/2010 11:13       5.91         NaN  United Kingdom
# 5417         1  12/3/2010 11:13       5.06         NaN  United Kingdom
# 5418         1  12/3/2010 11:13       4.21         NaN  United Kingdom
#
# [5419 rows x 9 columns]

# %%
df.describe()
# Out:
#               index       Quantity      UnitPrice     CustomerID
# count  541909.00000  541909.000000  541909.000000  406829.000000
# mean   270954.00000       9.552250       4.611114   15287.690570
# std    156435.79785     218.081158      96.759853    1713.600303
# min         0.00000  -80995.000000  -11062.060000   12346.000000
# 25%    135477.00000       1.000000       1.250000   13953.000000
# 50%    270954.00000       3.000000       2.080000   15152.000000
# 75%    406431.00000      10.000000       4.130000   16791.000000
# max    541908.00000   80995.000000   38970.000000   18287.000000

# %%
df.isnull().sum()
# Out:
# index               0
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['index', 'InvoiceNo', 'StockCode', 'Description', 'Quantity',
#        'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# index               0
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df['CustomerID'].fillna(value='00000',inplace=True)

# %%
df['CustomerID'].isnull().any()
# Out:
# False

# %%
df['Description'].fillna(value='unknown',inplace=True)

# %%
df.isnull().sum()
# Out:
# index          0
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
sns.countplot(x='Country',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='Country',y='UnitPrice',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='Country',y='Quantity',data=df)
plt.xticks(rotation=90)
plt.show()
